# %%
import os
import matplotlib.pyplot as plt
import time, os, json
import pandas as pd
from scipy import stats
import scipy
from tqdm import tqdm
import seaborn as sns
import pdb
import optax
from functools import partial
import math
import csv
import time
import numpy
from pdb import set_trace
from dataclasses import dataclass

import jax
from jax import random 
from jax.config import config
import jax.numpy as np
from jax import vmap
from jax.lib import xla_bridge

print("jax backend {}".format(xla_bridge.get_backend().platform))

from SSN_classes import SSN2DTopoV1_ONOFF_local, SSN2DTopoV1
import util
from util import take_log, load_param_from_csv
from analysis import param_ratios_two_layer
from visualization import (
    plot_losses,
    plot_losses_two_stage,
    plot_results_two_layers,
    plot_sigmoid_outputs,
    plot_training_accs,
)
import training_supp 
from training import *
from parameters import *
# Out:
# C:\Users\jozsa\AppData\Local\Temp\ipykernel_17520\2602351883.py:21: DeprecationWarning: Accessing jax.config via the jax.config submodule is deprecated.
#   from jax.config import config
# jax backend cpu

# %%
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"] = ".XX"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"] = "platform"

# %%
# Calculate find A and save
# BW_Grating(JiaGrating) is called 81 times and spatial_frequency is always 0.05235987755982988
ssn_mid = SSN2DTopoV1_ONOFF_local(
    ssn_pars=ssn_pars, # got c_E and c_I as new parameters
    grid_pars=grid_pars,
    conn_pars=conn_pars_m,
    filter_pars=filter_pars,
    stimuli_pars=stimuli_pars,
    ssn_layer_pars=ssn_layer_pars,
    is_mid = True,
)

ssn_pars.A = ssn_mid.A
if ssn_pars.phases == 4:
    ssn_pars.A2 = ssn_mid.A2

# %%
# Load orientation map, MJ
# ssn_ori_map = np.load(os.path.join(os.getcwd(), "ssn_map_uniform_good.npy"))

####################### TRAINING PARAMETERS #############################
epochs_to_save = np.insert(
    (np.unique(np.linspace(1, training_pars.epochs, training_pars.num_epochs_to_save).astype(int))), 0, 0
)

constant_ssn_pars = dict(
    ssn_pars=ssn_pars,
    grid_pars=grid_pars,
    conn_pars_m=conn_pars_m,
    conn_pars_s=conn_pars_s,
    gE=ssn_layer_pars.gE,
    gI=ssn_layer_pars.gI,
    filter_pars=filter_pars,
    conv_pars=conv_pars,# this got a lot of new stuff in it that might be a problem
    loss_pars=loss_pars,
    noise_type="poisson",
)


##################### SAVE RESULTS ###############################

# Name of results csv
home_dir = os.getcwd()

# Specify folder to save results
results_dir = os.path.join(
    home_dir,
    "results",
    "16-10",
    "phases_"
    + str(ssn_pars.phases)
    + "k_"
    + str(filter_pars.k)
    + "sigma_g"
    + str(filter_pars.sigma_g)
    + "gE_"
    + str(ssn_layer_pars.gE_m),
)

if os.path.exists(results_dir) == False:
    os.makedirs(results_dir)

# Specify results filename
run_dir = os.path.join(
    results_dir,
    "set_"
    + str("C") # init_set_m = "C" but I removed it for now
    + "_sig_noise_"
    + str(training_pars.sig_noise)
    + "_batch"
    + str(training_pars.batch_size)
    + "_lamw"
    + str(loss_pars.lambda_w),
)

# results_filename = None
results_filename = os.path.join(run_dir + "_results.csv")

# %%
########### TRAINING ############
(
    [ssn_layer_pars, readout_pars],
    val_loss_per_epoch,
    training_losses,
    training_accs,
    train_sig_inputs,
    train_sig_outputs,
    val_sig_inputs,
    val_sig_outputs,
    epoch_c,
    save_w_sigs,
) = new_two_stage_training(
    ssn_layer_pars,
    sig_pars,
    training_pars,
    constant_ssn_pars,
    stimuli_pars,
    results_filename=results_filename,
    results_dir=run_dir,
    extra_stop=2,
    # ssn_ori_map=ssn_ori_map,
)

print("new_pars ", ssn_layer_pars, readout_pars)

# Save training and validation losses
np.save(os.path.join(run_dir + "_training_losses.npy"), training_losses)
np.save(os.path.join(run_dir + "_validation_losses.npy"), val_loss_per_epoch)

# Plot losses
losses_dir = os.path.join(run_dir + "_losses")
plot_losses_two_stage(
    training_losses, val_loss_per_epoch, epoch_c=epoch_c, save=losses_dir, inset=False
)

# Plot results
results_plot_dir = os.path.join(run_dir + "_results")
plot_results_two_layers(
    results_filename, bernoulli=False, epoch_c=epoch_c, save=results_plot_dir
)

# Plot sigmoid
sig_dir = os.path.join(run_dir + "_sigmoid")
plot_sigmoid_outputs(
    train_sig_input=train_sig_inputs,
    val_sig_input=val_sig_inputs,
    train_sig_output=train_sig_outputs,
    val_sig_output=val_sig_outputs,
    epoch_c=epoch_c,
    save=sig_dir,
)


# Plot training_accs
training_accs_dir = os.path.join(run_dir + "_training_accs")
plot_training_accs(training_accs, epoch_c=epoch_c, save=training_accs_dir)
# Out:
# Creating new orientation map
# [[108.19311   33.916954 169.09836   62.805283  56.803688 129.52716
#   130.11998  136.36526    8.732875]
#  [152.88689  164.51344  110.01795   25.17708   12.181717 151.84813
#   175.1992   113.48331   51.224125]
#  [111.67828   20.04771  144.26273  140.02232  122.48022  156.74133
#    18.940832 102.344925 171.31766 ]
#  [ 61.634834  28.57898   80.449936  78.70014  100.129875  62.74411
#    18.420322 108.31922   66.628365]
#  [ 83.609215 150.90031  161.15598  102.46763   92.50887   45.144066
#    10.190314  69.8713    47.56116 ]
#  [ 84.08535  171.63354   23.4578    21.299782  57.956406  55.425255
#   159.30405  140.09622  166.80482 ]
#  [134.2883   151.80142   96.722275 158.28394   28.813362 152.23798
#   146.6488    97.08842  176.18513 ]
#  [ 97.50743  149.76422   66.56957  123.764275  72.56666   84.74236
#   160.06273   75.653984 101.23207 ]
#  [ 50.724464  31.922665  39.812393  89.47824   70.492424  43.49713
#    26.18861   51.772022 104.793015]]
# Training model for 3 epochs  with learning rate 0.001, sig_noise 2.0 at offset 4.0, lam_w 1, batch size 50, noise_type poisson
# Loss parameters dx 1, w 1
# Saving results to csv  C:\Users\jozsa\Desktop\Postdoc 2023-24\ABL-MJ\results\16-10\phases_2k_1.0471975511965976sigma_g0.1875gE_0.3\set_C_sig_noise_2.0_batch50_lamw1_results.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 13
#       1 ########### TRAINING ############
#       2 (
#       3     [ssn_layer_pars, readout_pars],
#       4     val_loss_per_epoch,
#       5     training_losses,
#       6     training_accs,
#       7     train_sig_inputs,
#       8     train_sig_outputs,
#       9     val_sig_inputs,
#      10     val_sig_outputs,
#      11     epoch_c,
#      12     save_w_sigs,
# ---> 13 ) = new_two_stage_training(
#      14     ssn_layer_pars,
#      15     sig_pars,
#      16     training_pars,
#      17     constant_ssn_pars,
#      18     stimuli_pars,
#      19     results_filename=results_filename,
#      20     results_dir=run_dir,
#      21     extra_stop=2,
#      22     # ssn_ori_map=ssn_ori_map,
#      23 )
#      25 print("new_pars ", ssn_layer_pars, readout_pars)
#      27 # Save training and validation losses
#
# File ~\Desktop\Postdoc 2023-24\ABL-MJ\training.py:161, in new_two_stage_training(ssn_layer_pars, sigm_pars, training_pars, constant_ssn_pars, stimuli_pars, results_filename, second_eta, test_size, results_dir, early_stop, extra_stop, ssn_ori_map)
#     150 constant_ssn_pars = generate_noise(
#     151     constant_ssn_pars,
#     152     sig_noise=sig_noise,
#     153     batch_size=batch_size,
#     154     length=w_sig.shape[0],
#     155 )
#     157 # Compute loss and gradient
#     158 [
#     159     epoch_loss,
#     160     [epoch_all_losses, train_true_acc, train_delta_x, train_x, train_r_ref],
# --> 161 ], grad = loss_and_grad_readout(
#     162     ssn_layer_pars, readout_pars, constant_ssn_pars, train_data, debug_flag
#     163 )
#     165 training_losses.append(epoch_loss)
#     166 if epoch == 0:
#
#     [... skipping hidden 8 frame]
#
# File ~\Desktop\Postdoc 2023-24\ABL-MJ\training_supp.py:482, in loss(ssn_layer_pars, readout_pars, constant_ssn_pars, data, debug_flag)
#     473 def loss(ssn_layer_pars, readout_pars, constant_ssn_pars, data, debug_flag=False):
#     474     """
#     475     Function to take gradient with respect to. Output returned as two variables (jax grad takes gradient with respect to first output)
#     476     Inputs:
#    (...)
#     479         total loss to take gradient with respect to
#     480     """
# --> 482     total_loss, all_losses, pred_label, sig_input, x, max_rates = model(
#     483         ssn_layer_pars=ssn_layer_pars,
#     484         readout_pars=readout_pars,
#     485         constant_ssn_pars=constant_ssn_pars,
#     486         data=data,
#     487         debug_flag=debug_flag,
#     488     )
#     489     loss = np.mean(total_loss)
#     490     all_losses = np.mean(all_losses, axis=0)
#
# File ~\Desktop\Postdoc 2023-24\ABL-MJ\training_supp.py:467, in model(ssn_layer_pars, readout_pars, constant_ssn_pars, data, debug_flag)
#     465 noise_ref = constant_ssn_pars['noise_ref']
#     466 noise_target = constant_ssn_pars['noise_target']
# --> 467 noise_type = constant_ssn_pars['noise_type']
#     468 train_ori = constant_ssn_pars['train_ori']
#     470 return vmap_model_jit(logJ_2x2, logs_2x2, c_E, c_I, f_E, f_I, w_sig, b_sig, sigma_oris, kappa_pre, kappa_post, ssn_mid_ori_map, ssn_mid_ori_map, data, ssn_pars, grid_pars, conn_pars_m, conn_pars_s, gE_m, gI_m, gE_s, gI_s, filter_pars, conv_pars, loss_pars, noise_ref, noise_target, noise_type, train_ori, debug_flag)
#
# KeyError: 'noise_type'
